# %% [markdown]
# <a href="https://colab.research.google.com/github/WelfLowe/ML4developers/blob/main/Improvement_stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
dates = ['31.07.2023','05.08.2023' ,'06.09.2023','08.09.2023']
metrics = [
    [21.714285714285715,
      18.5,
      0.4642857142857143,
      8.933333333333334,
      5.866666666666666,
      16.6],
    [16.071428571428573,
      12.642857142857142,
      0.42857142857142855,
      8.75,
      5.625,
      20.375],
    [12.03571429,
      7.82142857,
      0.21428571428571427,
      7.72727273,
      4.95454545,
      28.40909091],
    [11.5,
     7.35714286,
     0.17857142857142858,
     7.47826087,
     5.65217391,
     28.47826087]
    ]
metrics_np = np.array(metrics)
data_series = np.transpose(metrics_np)
data_series
# Out:
# array([[21.71428571, 16.07142857, 12.03571429, 11.5       ],
#        [18.5       , 12.64285714,  7.82142857,  7.35714286],
#        [ 0.46428571,  0.42857143,  0.21428571,  0.17857143],
#        [ 8.93333333,  8.75      ,  7.72727273,  7.47826087],
#        [ 5.86666667,  5.625     ,  4.95454545,  5.65217391],
#        [16.6       , 20.375     , 28.40909091, 28.47826087]])

# %%
for row in np.delete(data_series, 2, 0):
  print(row)
  plt.plot(dates, row)
plt.xlabel("Table date")
plt.ylabel("Performance")
plt.title("Means of all test cases")
plt.legend(['Rank 10 (all)', 'Rank 25 (all)', 'Rank 10 (conv)', 'Rank 25 (conv)', 'Rank (conv at)'])

plt.show()
# Out:
# [21.71428571 16.07142857 12.03571429 11.5       ]
# [18.5        12.64285714  7.82142857  7.35714286]
# [8.93333333 8.75       7.72727273 7.47826087]
# [5.86666667 5.625      4.95454545 5.65217391]
# [16.6        20.375      28.40909091 28.47826087]

# %%
print(data_series[2,:])
plt.plot(dates, data_series[2,:])
plt.xlabel("Table date")
plt.ylabel("Performance")
plt.title("Converging cases")
plt.legend(['Convergence %'])

plt.show()
# Out:
# [0.46428571 0.42857143 0.21428571 0.17857143]
