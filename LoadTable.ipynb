# %% [markdown]
# <a href="https://colab.research.google.com/github/WelfLowe/ML4developers/blob/main/LoadTable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Loads the Sypmtom Table into a Dataframe

# %%
import pandas as pd
import requests
from io import StringIO

# %% [markdown]
# Token expires 20.12.2023. Get a new fine-grained access token [here](https://github.com/settings/tokens?type=beta). Don't forget to set read access to repository contnt.

# %%
token = "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"
owner = 'WelfLowe'
repo = 'SymptomChecker'
path = 'Tabelle%20Syptomchecker%2028.10.2022%20(cut).csv'

# send a request
request_url = 'https://api.github.com/repos/{owner}/{repo}/contents/{path}'.format(owner=owner, repo=repo, path=path)
print (request_url)
r = requests.get(
    request_url,
    headers={
              'accept': 'application/vnd.github.v3.raw',
              'authorization': 'token {}'.format(token)
            }
    )
# convert string to StringIO object
string_io_obj = StringIO(r.text)

# Load data to df
df = pd.read_csv(string_io_obj, sep=";", on_bad_lines='skip')
df
# Out:
# https://api.github.com/repos/WelfLowe/SymptomChecker/contents/Tabelle%20Syptomchecker%2028.10.2022%20(cut).csv
#                                            Krankheiten            Hund/Katze  \
# 0                                                Abort                   NaN
# 1                                              Abszess                   NaN
# 2                                 Analdrüsenentzündung                   NaN
# 3                                          Anaplasmose                   NaN
# 4                Arthrose (Chronische Gelenkentzündung                   NaN
# ..                                                 ...                   ...
# 314                       Kokzidienbefall (Kokzidiose)             Durchfall
# 315            Kollaps der Luftröhre (Trachealkollaps)      Trockener Husten
# 316  Belastungsinduzierte Schwäche beim Labrador (e...     schaukelnder Gang
# 317              Kopfschiefhaltung (Vestibulärsyndrom)             Erbrechen
# ...

# %%
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
df_symptome = df.drop(df.columns[[0, 1]], axis=1)
df_symptome.head()
# Out:
#                  Symptom 1                     Symptom 2  \
# 0  Blutung aus der Scheide  Lecken im erkrankten Bereich
# 1          Schmerzen lokal             Körperregion warm
# 2           Schlittenfahen               Schmerzen lokal
# 3                   Fieber              Abgeschlagenheit
# 4                Schmerzen              Gelenkschwellung
#
#                       Symptom 3        Symptom 4             Symptom 5  \
# 0                           NaN              NaN                   NaN
# 1                    Schwellung     Geruch übler                Fieber
# 2  Lecken im erkrankten Bereich              NaN                   NaN
# 3                     Müdigkeit  Bewegungsunlust  Blutung aus der Nase
# 4                      Lahmheit  Bewegungsunlust            Gang steif
#
#                       Symptom 6                        Symptom 7  \
# 0                           NaN                              NaN
# ...

# %%
df_krankheit = df[["Krankheiten"]]
df_krankheit.head()
# Out:
#                              Krankheiten
# 0                                  Abort
# 1                                Abszess
# 2                   Analdrüsenentzündung
# 3                            Anaplasmose
# 4  Arthrose (Chronische Gelenkentzündung

# %%
all_symptoms = set()
for col in df_symptome:
    symp_col_set = set(df_symptome[col].unique())
    all_symptoms = all_symptoms.union(symp_col_set)
all_symptoms = {x for x in all_symptoms if x==x}
print(sorted(all_symptoms))
# Out:
# [', M', '24 h nach Abfall der Lörpertemperatur keine Wehen', '4 Stunden nach Geburtsbeginn kein Welpe', 'Abfall der Körpertemperatur', 'Abgeschlagenheit', 'Abgestorbene Haut an den Fußballen', 'Abmagerung', 'Abnahme Muskelnasse (Muskelatrophie in Schulterregion)', 'Abnahme der Muskelmasse', 'Abnirme Beweglichkeit des betroffenen Beines', 'Abnormale Atemgeräusche', 'Abnorme Gelenkhaltung', 'Abnorme Sitzposition', 'Abnorme Winkelung des betroffenen Beines', 'Abort', 'Absenken des Kopfes', 'Absinken der im After gemessenen Temperatur', 'Absterben von Gewebe', 'Abszesse', 'Aderhaut gelb (Sklera gelb)', 'Aggresivität', 'Aktivität gesteigert', 'Allgemeinbefinden gestört', 'Allgemeinbefinden ist gestört', 'Angst', 'Angstzustände', 'Ansammlung von Harn im Bauch bei Ruptur des Harnleiters', 'Anstrengung beim Kotansatz', 'Anämie', 'Apathie', 'Apetitlosigkeit', 'Appetit', 'Appetit erhöht', 'Appetit gesteigert', 'Appetit reduziert', 'Appetitlosigkeit', 'Appetitlosigkeit (Anorexie)', 'Appetitmang
# ...

# %%
all_diseases = df_krankheit.Krankheiten.unique()
print(sorted(all_diseases))
# Out:
# ['(Ellenbogengelenkdysplasie (ED)', 'Abort', 'Abszess', 'Adenokarzinom der Haut', 'Akne (Pyodermie)', 'Aktinische Keratose', 'Aktinomykose', 'Akute blutige Magen-Darm-Entzündung (akute hämorrhagische Gastroenteritis)', 'Akutes Atemnotsyndrom (ARDS)', 'Allergie', 'Allergischer Schock (Anaphylaxie)', 'Amöbeninfektion', 'Analdrüsenentzündung', 'Analdrüsenkrebs (Adenokarzinom)', 'Anaplasmose', 'Angeborene Gefäßmissbildeung der Leber-Pfortader(Primäre Pfortaderhypoplasie)', 'Angeborene Keratokonjunktivitis sicca (KCS)', 'Angeborene Linsentrübung (Katarakt)', 'Angeborene Missbildung des Herzen Trikuspidalkappe', 'Angeborene Missbildung des Herzens - Pulmonalstenose', 'Angeborene Missbildung des Herzens - Vorhofseptumdefekt', 'Angeborenes Glaukom', 'Anormale Proteinproduktion (Paraproteinämie)', 'Anreicherung harnpflichtiger Stoffe (Urämie)', 'Arterio-venöse Fistel', 'Arthritis septische', 'Arthrose (Chronische Gelenkentzündung', 'Aspirationspneumonie', 'Asthma', 'Asthma (Chronische obstruk
# ...
